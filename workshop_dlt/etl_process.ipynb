# %%
import pandas as pd

# %%
# !pip install dlt[duckdb]
# Out:
# Collecting dlt[duckdb]
#   Downloading dlt-1.6.1-py3-none-any.whl.metadata (11 kB)
# Collecting PyYAML>=5.4.1 (from dlt[duckdb])
#   Downloading PyYAML-6.0.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.1 kB)
# Collecting click>=7.1 (from dlt[duckdb])
#   Downloading click-8.1.8-py3-none-any.whl.metadata (2.3 kB)
# Collecting fsspec>=2022.4.0 (from dlt[duckdb])
#   Downloading fsspec-2025.2.0-py3-none-any.whl.metadata (11 kB)
# Collecting gitpython>=3.1.29 (from dlt[duckdb])
#   Downloading GitPython-3.1.44-py3-none-any.whl.metadata (13 kB)
# Collecting giturlparse>=0.10.0 (from dlt[duckdb])
#   Downloading giturlparse-0.12.0-py2.py3-none-any.whl.metadata (4.5 kB)
# Collecting hexbytes>=0.2.2 (from dlt[duckdb])
#   Downloading hexbytes-1.3.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting humanize>=4.4.0 (from dlt[duckdb])
#   Downloading humanize-4.12.0-py3-none-any.whl.metadata (7.8 kB)
# Collecting jsonpath-ng>=1.5.3 (from dlt[duckdb])
#   Downloading jsonpath_ng-1.7.0-py3-none-any.whl.metadata (18 kB)
# Collecting makefun>=1.15.0 (from dlt[duckdb])
#   Downloading makefun-1.15.6-py2.py3-none-any.whl.metadata (3.2 kB)
# Collecting orjson!=3.10.1,!=3.9.11,!=3.9.12,!=3.9.13,!=3.9.14,<4,>=3.6.7 (from dlt[duckdb])
#   Downloading orjson-3.10.15-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.8/41.8 kB 1.8 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=21.1 in /home/timosii/de_zoomcamp/.venv/lib/python3.10/site-packages (from dlt[duckdb]) (24.2)
# Collecting pathvalidate>=2.5.2 (from dlt[duckdb])
#   Downloading pathvalidate-3.2.3-py3-none-any.whl.metadata (12 kB)
# Collecting pendulum>=2.1.2 (from dlt[duckdb])
#   Downloading pendulum-3.0.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.9 kB)
# Collecting pluggy>=1.3.0 (from dlt[duckdb])
#   Downloading pluggy-1.5.0-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: pytz>=2022.6 in /home/timosii/de_zoomcamp/.venv/lib/python3.10/site-packages (from dlt[duckdb]) (2024.2)
# Collecting requests>=2.26.0 (from dlt[duckdb])
#   Downloading requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting requirements-parser>=0.5.0 (from dlt[duckdb])
#   Downloading requirements_parser-0.11.0-py3-none-any.whl.metadata (4.7 kB)
# Collecting rich-argparse<2.0.0,>=1.6.0 (from dlt[duckdb])
#   Downloading rich_argparse-1.7.0-py3-none-any.whl.metadata (14 kB)
# Collecting semver>=3.0.0 (from dlt[duckdb])
#   Downloading semver-3.0.4-py3-none-any.whl.metadata (6.8 kB)
# Collecting setuptools>=65.6.0 (from dlt[duckdb])
#   Downloading setuptools-75.8.0-py3-none-any.whl.metadata (6.7 kB)
# Collecting simplejson>=3.17.5 (from dlt[duckdb])
#   Downloading simplejson-3.20.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.2 kB)
# Collecting tenacity>=8.0.2 (from dlt[duckdb])
#   Downloading tenacity-9.0.0-py3-none-any.whl.metadata (1.2 kB)
# Collecting tomlkit>=0.11.3 (from dlt[duckdb])
#   Downloading tomlkit-0.13.2-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: typing-extensions>=4.8.0 in /home/timosii/de_zoomcamp/.venv/lib/python3.10/site-packages (from dlt[duckdb]) (4.12.2)
# Requirement already satisfied: tzdata>=2022.1 in /home/timosii/de_zoomcamp/.venv/lib/python3.10/site-packages (from dlt[duckdb]) (2025.1)
# Collecting duckdb>=0.9 (from dlt[duckdb])
#   Downloading duckdb-1.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (966 bytes)
# Collecting gitdb<5,>=4.0.1 (from gitpython>=3.1.29->dlt[duckdb])
#   Downloading gitdb-4.0.12-py3-none-any.whl.metadata (1.2 kB)
# Collecting ply (from jsonpath-ng>=1.5.3->dlt[duckdb])
#   Downloading ply-3.11-py2.py3-none-any.whl.metadata (844 bytes)
# Requirement already satisfied: python-dateutil>=2.6 in /home/timosii/de_zoomcamp/.venv/lib/python3.10/site-packages (from pendulum>=2.1.2->dlt[duckdb]) (2.9.0.post0)
# Collecting time-machine>=2.6.0 (from pendulum>=2.1.2->dlt[duckdb])
#   Downloading time_machine-2.16.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (21 kB)
# Collecting charset-normalizer<4,>=2 (from requests>=2.26.0->dlt[duckdb])
#   Downloading charset_normalizer-3.4.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (35 kB)
# Collecting idna<4,>=2.5 (from requests>=2.26.0->dlt[duckdb])
#   Downloading idna-3.10-py3-none-any.whl.metadata (10 kB)
# Collecting urllib3<3,>=1.21.1 (from requests>=2.26.0->dlt[duckdb])
#   Downloading urllib3-2.3.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting certifi>=2017.4.17 (from requests>=2.26.0->dlt[duckdb])
#   Downloading certifi-2025.1.31-py3-none-any.whl.metadata (2.5 kB)
# Collecting types-setuptools>=69.1.0 (from requirements-parser>=0.5.0->dlt[duckdb])
#   Downloading types_setuptools-75.8.0.20250210-py3-none-any.whl.metadata (2.2 kB)
# Collecting rich>=11.0.0 (from rich-argparse<2.0.0,>=1.6.0->dlt[duckdb])
#   Downloading rich-13.9.4-py3-none-any.whl.metadata (18 kB)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython>=3.1.29->dlt[duckdb])
#   Downloading smmap-5.0.2-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: six>=1.5 in /home/timosii/de_zoomcamp/.venv/lib/python3.10/site-packages (from python-dateutil>=2.6->pendulum>=2.1.2->dlt[duckdb]) (1.17.0)
# Collecting markdown-it-py>=2.2.0 (from rich>=11.0.0->rich-argparse<2.0.0,>=1.6.0->dlt[duckdb])
#   Downloading markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/timosii/de_zoomcamp/.venv/lib/python3.10/site-packages (from rich>=11.0.0->rich-argparse<2.0.0,>=1.6.0->dlt[duckdb]) (2.19.1)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich>=11.0.0->rich-argparse<2.0.0,>=1.6.0->dlt[duckdb])
#   Downloading mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Downloading click-8.1.8-py3-none-any.whl (98 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.2/98.2 kB 1.8 MB/s eta 0:00:00a 0:00:01
# Downloading duckdb-1.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (20.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.2/20.2 MB 7.4 MB/s eta 0:00:0000:0100:01
# Downloading fsspec-2025.2.0-py3-none-any.whl (184 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.5/184.5 kB 6.8 MB/s eta 0:00:00
# Downloading GitPython-3.1.44-py3-none-any.whl (207 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.6/207.6 kB 6.7 MB/s eta 0:00:00
# Downloading giturlparse-0.12.0-py2.py3-none-any.whl (15 kB)
# Downloading hexbytes-1.3.0-py3-none-any.whl (4.9 kB)
# Downloading humanize-4.12.0-py3-none-any.whl (127 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.4/127.4 kB 5.9 MB/s eta 0:00:00
# Downloading jsonpath_ng-1.7.0-py3-none-any.whl (30 kB)
# Downloading makefun-1.15.6-py2.py3-none-any.whl (22 kB)
# Downloading orjson-3.10.15-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (130 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.3/130.3 kB 5.9 MB/s eta 0:00:00
# Downloading pathvalidate-3.2.3-py3-none-any.whl (24 kB)
# Downloading pendulum-3.0.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (384 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 384.9/384.9 kB 6.3 MB/s eta 0:00:00a 0:00:01
# Downloading pluggy-1.5.0-py3-none-any.whl (20 kB)
# Downloading PyYAML-6.0.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (751 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 751.2/751.2 kB 6.6 MB/s eta 0:00:00a 0:00:01
# Downloading requests-2.32.3-py3-none-any.whl (64 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.9/64.9 kB 5.1 MB/s eta 0:00:00
# Downloading requirements_parser-0.11.0-py3-none-any.whl (14 kB)
# Downloading rich_argparse-1.7.0-py3-none-any.whl (25 kB)
# Downloading semver-3.0.4-py3-none-any.whl (17 kB)
# Downloading setuptools-75.8.0-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 6.2 MB/s eta 0:00:0000:0100:01
# Downloading simplejson-3.20.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (138 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.0/138.0 kB 6.2 MB/s eta 0:00:00
# Downloading tenacity-9.0.0-py3-none-any.whl (28 kB)
# Downloading tomlkit-0.13.2-py3-none-any.whl (37 kB)
# Downloading dlt-1.6.1-py3-none-any.whl (884 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 884.3/884.3 kB 6.7 MB/s eta 0:00:00a 0:00:01
# Downloading certifi-2025.1.31-py3-none-any.whl (166 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.4/166.4 kB 6.8 MB/s eta 0:00:00
# Downloading charset_normalizer-3.4.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (146 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 146.1/146.1 kB 6.5 MB/s eta 0:00:00
# Downloading gitdb-4.0.12-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 kB 4.6 MB/s eta 0:00:00
# Downloading idna-3.10-py3-none-any.whl (70 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.4/70.4 kB 5.6 MB/s eta 0:00:00
# Downloading rich-13.9.4-py3-none-any.whl (242 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 242.4/242.4 kB 7.4 MB/s eta 0:00:00
# Downloading time_machine-2.16.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (34 kB)
# Downloading types_setuptools-75.8.0.20250210-py3-none-any.whl (71 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.5/71.5 kB 5.4 MB/s eta 0:00:00
# Downloading urllib3-2.3.0-py3-none-any.whl (128 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.4/128.4 kB 7.3 MB/s eta 0:00:00
# Downloading ply-3.11-py2.py3-none-any.whl (49 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.6/49.6 kB 4.6 MB/s eta 0:00:00
# Downloading markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.5/87.5 kB 6.7 MB/s eta 0:00:00
# Downloading smmap-5.0.2-py3-none-any.whl (24 kB)
# Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Installing collected packages: ply, makefun, urllib3, types-setuptools, tomlkit, tenacity, smmap, simplejson, setuptools, semver, PyYAML, pluggy, pathvalidate, orjson, mdurl, jsonpath-ng, idna, humanize, hexbytes, giturlparse, fsspec, duckdb, click, charset-normalizer, certifi, time-machine, requirements-parser, requests, markdown-it-py, gitdb, rich, pendulum, gitpython, rich-argparse, dlt
# Successfully installed PyYAML-6.0.2 certifi-2025.1.31 charset-normalizer-3.4.1 click-8.1.8 dlt-1.6.1 duckdb-1.2.0 fsspec-2025.2.0 gitdb-4.0.12 gitpython-3.1.44 giturlparse-0.12.0 hexbytes-1.3.0 humanize-4.12.0 idna-3.10 jsonpath-ng-1.7.0 makefun-1.15.6 markdown-it-py-3.0.0 mdurl-0.1.2 orjson-3.10.15 pathvalidate-3.2.3 pendulum-3.0.0 pluggy-1.5.0 ply-3.11 requests-2.32.3 requirements-parser-0.11.0 rich-13.9.4 rich-argparse-1.7.0 semver-3.0.4 setuptools-75.8.0 simplejson-3.20.1 smmap-5.0.2 tenacity-9.0.0 time-machine-2.16.0 tomlkit-0.13.2 types-setuptools-75.8.0.20250210 urllib3-2.3.0
#
# [notice] A new release of pip is available: 24.1.1 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
# !dlt --version
# Out:
# dlt 1.6.1

# %%
import dlt
from dlt.sources.helpers.rest_client import RESTClient
from dlt.sources.helpers.rest_client.paginators import PageNumberPaginator


@dlt.resource(name="rides")   # <--- The name of the resource (will be used as the table name)
def ny_taxi():
    client = RESTClient(
        base_url="https://us-central1-dlthub-analytics.cloudfunctions.net",
        paginator=PageNumberPaginator(
            base_page=1,
            total_path=None
        )
    )

    for page in client.paginate("data_engineering_zoomcamp_api"):    # <--- API endpoint for retrieving taxi ride data
        yield page   # <--- yield data to manage memory


pipeline = dlt.pipeline(
    pipeline_name="ny_taxi_pipeline",
    destination="duckdb",
    dataset_name="ny_taxi_data"
)

# %%
load_info = pipeline.run(ny_taxi)
print(load_info)
# Out:
# Pipeline ny_taxi_pipeline load step completed in 1.27 seconds
# 1 load package(s) were loaded to destination duckdb and into dataset ny_taxi_data
# The duckdb destination used duckdb:////home/timosii/de_zoomcamp/workshop_dlt/ny_taxi_pipeline.duckdb location to store data
# Load package 1739660587.084195 is LOADED and contains no failed jobs

# %%
# !pip install google
# Out:
# Collecting google
#   Downloading google-3.0.0-py2.py3-none-any.whl.metadata (627 bytes)
# Collecting beautifulsoup4 (from google)
#   Downloading beautifulsoup4-4.13.3-py3-none-any.whl.metadata (3.8 kB)
# Collecting soupsieve>1.2 (from beautifulsoup4->google)
#   Downloading soupsieve-2.6-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: typing-extensions>=4.0.0 in /home/timosii/de_zoomcamp/.venv/lib/python3.10/site-packages (from beautifulsoup4->google) (4.12.2)
# Downloading google-3.0.0-py2.py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.3/45.3 kB 847.0 kB/s eta 0:00:000:00:01
# Downloading beautifulsoup4-4.13.3-py3-none-any.whl (186 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 186.0/186.0 kB 2.8 MB/s eta 0:00:00 0:00:01
# Downloading soupsieve-2.6-py3-none-any.whl (36 kB)
# Installing collected packages: soupsieve, beautifulsoup4, google
# Successfully installed beautifulsoup4-4.13.3 google-3.0.0 soupsieve-2.6
#
# [notice] A new release of pip is available: 24.1.1 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
import duckdb
# from google.colab import data_table
# data_table.enable_dataframe_formatter()

# A database '<pipeline_name>.duckdb' was created in working directory so just connect to it

# Connect to the DuckDB database
conn = duckdb.connect(f"{pipeline.pipeline_name}.duckdb")

# Set search path to the dataset
conn.sql(f"SET search_path = '{pipeline.dataset_name}'")

# Describe the dataset
conn.sql("DESCRIBE").df()
# Out:
#            database        schema                 name  \
# 0  ny_taxi_pipeline  ny_taxi_data           _dlt_loads
# 1  ny_taxi_pipeline  ny_taxi_data  _dlt_pipeline_state
# 2  ny_taxi_pipeline  ny_taxi_data         _dlt_version
# 3  ny_taxi_pipeline  ny_taxi_data                rides
#
#                                         column_names  \
# 0  [load_id, schema_name, status, inserted_at, sc...
# 1  [version, engine_version, pipeline_name, state...
# 2  [version, engine_version, inserted_at, schema_...
# 3  [end_lat, end_lon, fare_amt, passenger_count, ...
#
#                                         column_types  temporary
# 0  [VARCHAR, VARCHAR, BIGINT, TIMESTAMP WITH TIME...      False
# 1  [BIGINT, BIGINT, VARCHAR, VARCHAR, TIMESTAMP W...      False
# 2  [BIGINT, BIGINT, TIMESTAMP WITH TIME ZONE, VAR...      False
# 3  [DOUBLE, DOUBLE, DOUBLE, BIGINT, VARCHAR, DOUB...      False

# %%
df = pipeline.dataset(dataset_type="default").rides.df()
df
# Out:
#         end_lat    end_lon  fare_amt  passenger_count payment_type  start_lat  \
# 0     40.742963 -73.980072      45.0                1       Credit  40.641525
# 1     40.740187 -74.005698       6.5                1       Credit  40.722065
# 2     40.718043 -74.004745      12.5                5       Credit  40.761945
# 3     40.739637 -73.985233       4.9                1         CASH  40.749802
# 4     40.730032 -73.852693      25.7                1         CASH  40.776825
# ...         ...        ...       ...              ...          ...        ...
# 9995  40.783522 -73.970690       5.7                1         CASH  40.778560
# 9996  40.777200 -73.964197       4.1                1         CASH  40.779800
# 9997  40.780172 -73.957617       6.1                1         CASH  40.788388
# 9998  40.777342 -73.957242       5.7                1         CASH  40.773828
# 9999  40.757122 -73.986293       6.5                1       Credit  40.756313
#
#       start_lon  tip_amt  tolls_amt  total_amt  trip_distance  \
# 0    -73.787442      9.0       4.15      58.15          17.52
# 1    -74.009767      1.0       0.00       8.50           1.56
# 2    -73.983038      2.0       0.00      15.50           3.37
# 3    -73.992247      0.0       0.00       5.40           1.11
# 4    -73.949233      0.0       4.15      29.85          11.09
# ...         ...      ...        ...        ...            ...
# 9995 -73.953660      0.0       0.00       5.70           1.16
# 9996 -73.974297      0.0       0.00       4.10           0.89
# 9997 -73.976758      0.0       0.00       6.10           1.30
# 9998 -73.956690      0.0       0.00       6.20           0.97
# 9999 -73.972948      2.0       0.00       8.50           0.92
#
#         trip_dropoff_date_time     trip_pickup_date_time  surcharge  \
# 0    2009-06-14 23:48:00+00:00 2009-06-14 23:23:00+00:00        0.0
# 1    2009-06-18 17:43:00+00:00 2009-06-18 17:35:00+00:00        1.0
# 2    2009-06-10 18:27:00+00:00 2009-06-10 18:08:00+00:00        1.0
# 3    2009-06-14 23:58:00+00:00 2009-06-14 23:54:00+00:00        0.5
# 4    2009-06-13 13:23:00+00:00 2009-06-13 13:01:00+00:00        0.0
# ...                        ...                       ...        ...
# 9995 2009-06-19 11:28:00+00:00 2009-06-19 11:22:00+00:00        0.0
# 9996 2009-06-17 07:43:00+00:00 2009-06-17 07:41:00+00:00        0.0
# 9997 2009-06-19 11:46:00+00:00 2009-06-19 11:39:00+00:00        0.0
# 9998 2009-06-17 04:19:00+00:00 2009-06-17 04:13:00+00:00        0.5
# 9999 2009-06-17 08:34:00+00:00 2009-06-17 08:24:00+00:00        0.0
#
#      vendor_name       _dlt_load_id         _dlt_id  store_and_forward
# 0            VTS  1739660587.084195  xVxpPDx26Wghbw                NaN
# 1            VTS  1739660587.084195  wHp7h0bqRqfepg                NaN
# 2            VTS  1739660587.084195  9Ho7SWmSvIXxYA                NaN
# 3            VTS  1739660587.084195  KXixiSkmvvUfQg                NaN
# 4            VTS  1739660587.084195  29s0+sFksNWGNA                NaN
# ...          ...                ...             ...                ...
# 9995         VTS  1739660587.084195  ocgrfKgCFJ/m8w                NaN
# 9996         VTS  1739660587.084195  eoMYoGA7VxmPSA                NaN
# 9997         VTS  1739660587.084195  p5bKPw1nxncYSg                NaN
# 9998         VTS  1739660587.084195  /S/1ufy/VbsG3Q                NaN
# 9999         VTS  1739660587.084195  xQiunflVZ2Cf3A                NaN
#
# [10000 rows x 18 columns]

# %%
for col in df.columns:
    print(f"col {col}, nunique is: {df[f'{col}'].nunique()}")
# Out:
# col end_lat, nunique is: 9066
# col end_lon, nunique is: 8835
# col fare_amt, nunique is: 146
# col passenger_count, nunique is: 7
# col payment_type, nunique is: 5
# col start_lat, nunique is: 8902
# col start_lon, nunique is: 8713
# col tip_amt, nunique is: 232
# col tolls_amt, nunique is: 13
# col total_amt, nunique is: 680
# col trip_distance, nunique is: 1214
# col trip_dropoff_date_time, nunique is: 8704
# col trip_pickup_date_time, nunique is: 8768
# col surcharge, nunique is: 3
# col vendor_name, nunique is: 2
# col _dlt_load_id, nunique is: 1
# col _dlt_id, nunique is: 10000
# col store_and_forward, nunique is: 2

# %%
with pipeline.sql_client() as client:
    res = client.execute_sql(
            """
            SELECT
            AVG(date_diff('minute', trip_pickup_date_time, trip_dropoff_date_time))
            FROM rides;
            """
        )
    # Prints column values of the first row
    print(res)
# Out:
# [(12.3049,)]
